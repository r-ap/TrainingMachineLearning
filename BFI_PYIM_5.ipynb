# %% [markdown]
# <a href="https://colab.research.google.com/github/r-ap/TrainingMachineLearning/blob/main/BFI_PYIM_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# **Import Pandas**

# %%
import pandas as pd

# %% [markdown]
# ## Load Data dengan Pandas

# %% [markdown]
# ### Excel File
#
# **Load Data**

# %%
#Download data xlsx dari google drive dan disimpan di google colab (Hanya bisa di google colab)
# !gdown 1YOo-vYvlr5IyM3cEb32IHCPACrTrQ7pH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1YOo-vYvlr5IyM3cEb32IHCPACrTrQ7pH
# To: /content/data_penjualan.xlsx
# 100% 6.44k/6.44k [00:00<00:00, 15.2MB/s]

# %% [markdown]
# ### NOTES ###
#
# Jika mengunakan Google Colab hapus `content\` cukup menggunakan nama file nya

# %%
data_penjualan = pd.read_excel('content\data_penjualan.xlsx')

# %%
data_penjualan
# Out:
#         Bulan  Penjualan
# 0     Januari     1000.0
# 1    Februari      200.0
# 2       Maret     5000.0
# 3       April      654.0
# 4         Mei     1200.0
# 5        Juni      760.0
# 6        Juli     1000.0
# 7     Agustus     1100.0
# 8   September     1200.0
# 9     Oktober     1500.0
# 10   November     4000.0
# 11   Desember     7600.0

# %% [markdown]
# **Melihat list sheet di file Excel**

# %%
pd.ExcelFile('content\data_penjualan.xlsx').sheet_names
# Out:
# ['2020', '2021']

# %%
data_penjualan_2021 = pd.read_excel('content\data_penjualan.xlsx',sheet_name='2021')
data_penjualan_2021
# Out:
#         Bulan  Penjualan
# 0     Januari       1200
# 1    Februari       1500
# 2       Maret       4000
# 3       April       7600
# 4         Mei       1200
# 5        Juni        760
# 6        Juli       1000
# 7     Agustus       1100
# 8   September       1300
# 9     Oktober       1000
# 10   November       1100
# 11   Desember       1200

# %% [markdown]
# **Skiprows dan Skipfooter**

# %%
#Skiprows

pd.read_excel('content\data_penjualan.xlsx',sheet_name='2020',skiprows=3)
# Out:
#        Maret  5000.0
# 0      April   654.0
# 1        Mei  1200.0
# 2       Juni   760.0
# 3       Juli  1000.0
# 4    Agustus  1100.0
# 5  September  1200.0
# 6    Oktober  1500.0
# 7   November  4000.0
# 8   Desember  7600.0

# %%
#Skipfooter

pd.read_excel('content\data_penjualan.xlsx',sheet_name='2021',skipfooter=4)
# Out:
#       Bulan  Penjualan
# 0   Januari     1200.0
# 1  Februari     1500.0
# 2     Maret     4000.0
# 3     April     7600.0
# 4       Mei     1200.0
# 5      Juni      760.0
# 6      Juli     1000.0
# 7   Agustus     1100.0

# %%
data_penjualan_Sheet1 = pd.read_excel('content\data_penjualan.xlsx',sheet_name='Sheet1')
data_penjualan_Sheet1
# Out:
#    Data Penjualan 2021 Unnamed: 1
# 0                Bulan  Penjualan
# 1              Januari       1200
# 2             Februari       1500
# 3                Maret       4000
# 4                April       7600
# 5                  Mei       1200
# 6                 Juni        760
# 7                 Juli       1000
# 8              Agustus       1100
# 9            September       1300
# 10             Oktober       1000
# 11            November       1100
# 12            Desember       1200
# 13                 NaN        NaN
# 14               Total      22960

# %%
pd.read_excel('content\data_penjualan.xlsx',sheet_name='Sheet1',skipfooter=2,skiprows=1)
pd.read_excel('content\data_penjualan.xlsx',sheet_name='Sheet1',skipfooter=2,skiprows=1,header=None)
# Out:
#             0          1
# 0       Bulan  Penjualan
# 1     Januari       1200
# 2    Februari       1500
# 3       Maret       4000
# 4       April       7600
# 5         Mei       1200
# 6        Juni        760
# 7        Juli       1000
# 8     Agustus       1100
# 9   September       1300
# 10    Oktober       1000
# 11   November       1100
# 12   Desember       1200

# %%
type(data_penjualan)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Format Lainnya (CSV/Comma-Seperated_Value)
#
# Secara default, `pd.read_csv` akan 'mencari' tanda koma dan menetapkannya sebagai pemisah.

# %%
house_price = pd.read_csv('https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/main/kc_house_data.csv')
house_price
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# !wget https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/main/purchase_data.txt
# Out:
# --2022-07-01 16:05:26--  https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/main/purchase_data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15901932 (15M) [text/plain]
# Saving to: ‘purchase_data.txt’
#
# purchase_data.txt   100%[===================>]  15.17M  --.-KB/s    in 0.06s
#
# 2022-07-01 16:05:27 (263 MB/s) - ‘purchase_data.txt’ saved [15901932/15901932]

# %%
purchase_data = pd.read_csv('content\purchase_data.txt')
purchase_data
# Out:
#            user_id;timestamp;group;landing_page;purchased
# 0       851104;2017-01-21 22:11:48.556739;control;old_...
# 1       804228;2017-01-12 08:01:45.159739;control;old_...
# 2       661590;2017-01-11 16:55:06.154213;treatment;ne...
# 3       853541;2017-01-08 18:28:03.143765;treatment;ne...
# 4       864975;2017-01-21 01:52:26.210827;control;old_...
# ...                                                   ...
# 294473  751197;2017-01-03 22:28:38.630509;control;old_...
# 294474  945152;2017-01-12 00:51:57.078372;control;old_...
# 294475  734608;2017-01-22 11:45:03.439544;control;old_...
# 294476  697314;2017-01-15 01:20:28.957438;control;old_...
# 294477  715931;2017-01-16 12:40:24.467417;treatment;ne...
#
# [294478 rows x 1 columns]

# %%
purchase_data_semicolom = pd.read_csv('content\purchase_data.txt',delimiter=';')
purchase_data_semicolom
# Out:
#         user_id                   timestamp      group landing_page  purchased
# 0        851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1        804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2        661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3        853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4        864975  2017-01-21 01:52:26.210827    control     old_page          1
# ...         ...                         ...        ...          ...        ...
# 294473   751197  2017-01-03 22:28:38.630509    control     old_page          0
# 294474   945152  2017-01-12 00:51:57.078372    control     old_page          0
# 294475   734608  2017-01-22 11:45:03.439544    control     old_page          0
# 294476   697314  2017-01-15 01:20:28.957438    control     old_page          0
# 294477   715931  2017-01-16 12:40:24.467417  treatment     new_page          0
#
# ...

# %% [markdown]
# ### READ JSON ###

# %%
simple_json = pd.read_json('content\simple_json.json')
simple_json
# Out:
#      simple_json
# id          0001
# name        Cake
# ppu         0.55
# type       donut

# %% [markdown]
# ## Menampilkan dan Merangkum Informasi Data

# %% [markdown]
# **Menampilkan baris teratas**

# %%
house_price.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house_price.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# **Menampilkan baris terbawah**

# %%
house_price.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
house_price.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %% [markdown]
# **Menampilkan rangkuman struktur data**

# %%
house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# **Menampilkan rangkuman statistik data**

# %%
house_price.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Series

# %%
series = pd.Series(['a','b','c','d','e'])
series
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %% [markdown]
# **Akses nilai pada Series**

# %%
series.values
# Out:
# array(['a', 'b', 'c', 'd', 'e'], dtype=object)

# %% [markdown]
# **Akses Elemen Series**

# %%
series[0]
# Out:
# 'a'

# %%
series[0:2]
# Out:
# 0    a
# 1    b
# dtype: object

# %% [markdown]
# ## DataFrame

# %%
df = pd.DataFrame({
    'Nama' : ['A','B','C'],
    'Usia' : [1,2,3],
    'Alamat Rumah' : ['Jl. A', 'Jl. B', 'Jl. C']
})

df
# Out:
#   Nama  Usia Alamat Rumah
# 0    A     1        Jl. A
# 1    B     2        Jl. B
# 2    C     3        Jl. C

# %% [markdown]
# **Menampilkan Kolom**

# %%
df.columns
# Out:
# Index(['Nama', 'Usia', 'Alamat Rumah'], dtype='object')

# %% [markdown]
# **Menampilkan Index**

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# **Akses nilai pada DataFrame**

# %%
df.values
# Out:
# array([['A', 1, 'Jl. A'],
#        ['B', 2, 'Jl. B'],
#        ['C', 3, 'Jl. C']], dtype=object)

# %% [markdown]
# ### Akses Kolom
#
# `df['nama_kolom']`
#
# atau
#
# `df.nama_kolom` dengan syarat 'nama_kolom' sesuai dengan aturan penulisan nama variabel

# %%
df['Nama']
# Out:
# 0    A
# 1    B
# 2    C
# Name: Nama, dtype: object

# %%
df.Usia
# Out:
# 0    1
# 1    2
# 2    3
# Name: Usia, dtype: int64

# %%
df[['Nama','Usia']]
# Out:
#   Nama  Usia
# 0    A     1
# 1    B     2
# 2    C     3

# %% [markdown]
# ### Akses Baris

# %%
df_test = pd.DataFrame({'Nilai1':[2,6,9,1,7],'Nilai2':[4,9,10,4,6]},index=['A','B','C','D','E'])
df_test
# Out:
#    Nilai1  Nilai2
# A       2       4
# B       6       9
# C       9      10
# D       1       4
# E       7       6

# %%
df_test.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %% [markdown]
# **.loc**

# %%
df_test.loc['B']
# Out:
# Nilai1    6
# Nilai2    9
# Name: B, dtype: int64

# %%
df_test.loc[['A','B','C']]
# Out:
#    Nilai1  Nilai2
# A       2       4
# B       6       9
# C       9      10

# %%
df_test.loc[['B','D','E']]
# Out:
#    Nilai1  Nilai2
# B       6       9
# D       1       4
# E       7       6

# %%
df_test.loc['A','Nilai1']
# Out:
# 2

# %%
df_test.loc[['B','D'],'Nilai2']
# Out:
# B    9
# D    4
# Name: Nilai2, dtype: int64

# %% [markdown]
# **.iloc**

# %%
df_test.iloc[0]
# Out:
# Nilai1    2
# Nilai2    4
# Name: A, dtype: int64

# %%
df_test.iloc[2:4]
# Out:
#    Nilai1  Nilai2
# C       9      10
# D       1       4

# %%
df_test.iloc[4,0]
# Out:
# 7

# %%
df_test.iloc[2:4,1]
# Out:
# C    10
# D     4
# Name: Nilai2, dtype: int64

# %%
#house_price.index
#house_price.loc[2:4]
#house_price.iloc[2:4,0:2]
#house_price[['floors','grade']]

#house_price.loc[2:4,['floors','grade']]

house_price.iloc[2:4,[1,3,5]]

array1 = house_price.iloc[2:4,[1,3,5]].to_numpy()
# Out:
# numpy.ndarray

# %% [markdown]
# ### Manipulasi Index ###

# %% [markdown]
# Mengganti Index

# %%
house_price.head()
#mengganti index dengan column dataframe
house_price_by_id =house_price.set_index('id')

#mengganti index pada dataframe tanpa id tertentu
house_price_by_id.reset_index()
#house_price.reset_index()
#house_price.reset_index(drop=True)

#multi index

house_price.set_index(['id','date']).head()

#multi index hirarki

import numpy as np

array_np = [['bar','bar','baz','baz','foo','foo','quz','quz'],['one','two','one','two','one','two','one','two']]

df_random = pd.DataFrame(np.random.randn(8),index=array_np, columns=['nilai'])
df_random

df_random.loc[('bar','one')]
# Out:
# nilai    1.075904
# Name: (bar, one), dtype: float64

# %% [markdown]
# ## Manipulasi Kolom

# %%
house_price1 = house_price.copy()
house_price1.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# **Mengganti nama kolom**

# %%
house_price1.rename({'sqft_living':'living_area'},axis=1,inplace=True)  # axis = 1 --> Column axis = 0 --> row;  inplace untuk implement perubahan

house_price1.rename({0:'id_1'},axis=0)  # renam index
# Out:
#                id             date     price  bedrooms  bathrooms  \
# id_1   7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        living_area  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# id_1          1180      5650     1.0           0     0  ...        1180
# ...

# %% [markdown]
# **Menghapus kolom**

# %%
house_price1.drop(columns=['id', 'date'])
# Out:
#           price  bedrooms  bathrooms  living_area  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %% [markdown]
# **Menambah Kolom**

# %%
#Add Column
house_price1['total_rooms'] = house_price1['bedrooms'] + house_price1['bathrooms']

house_price1
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        living_area  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %% [markdown]
# ## Query/Filtering

# %%
house_price.head()

#house_price[(house_price['bedrooms'] >2)]


house_price[(house_price['bedrooms'] >= 2) & (house_price['price'] <= 3000000)]

house_price[(house_price['bedrooms'] + house_price['bathrooms'] >= 4) & (house_price['price'] <= 3000000)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# ...           ...              ...        ...       ...        ...
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21611   291310100  20150116T000000   400000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ## Grouping dan Aggregating

# %%
report_sales = pd.read_csv('https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/main/sales_data_sample.csv',encoding='latin-1')
report_sales


report_sales.groupby('STATUS').count()


report_sales.groupby('COUNTRY').sum()['SALES']


report_sales.groupby(['COUNTRY','STATUS']).sum()
# Out:
#                         ORDERNUMBER  QUANTITYORDERED  PRICEEACH  \
# COUNTRY     STATUS
# Australia   Disputed          52075              164     391.08
#             In Process       135460              532    1002.70
#             Shipped         1711306             5550   14055.36
# Austria     Resolved          81312              288     689.87
#             Shipped          483336             1686    4069.29
# Belgium     In Process        52115              111     394.86
#             Shipped          287572              963    2492.45
# Canada      Shipped          719223             2293    5957.05
# Denmark     Disputed          31218              174     300.00
#             Resolved          82616              253     695.52
#             Shipped          530633             1770    4508.37
# Finland     Shipped          944808             3192    7722.15
# France      In Process       135525              427    1059.20
# ...

# %%
report_sales.groupby(['COUNTRY','STATUS']).agg({'ORDERNUMBER':'sum','SALES':'sum','QUANTITYORDERED':'count','MONTH_ID':['min','max']})
# Out:
#                        ORDERNUMBER       SALES QUANTITYORDERED MONTH_ID
#                                sum         sum           count      min max
# COUNTRY     STATUS
# Australia   Disputed         52075    14378.09               5        5   5
#             In Process      135460    43971.43              13        5   5
#             Shipped        1711306   572273.58             167        1  12
# Austria     Resolved         81312    28550.59               8       10  10
#             Shipped         483336   173511.94              47        3  11
# Belgium     In Process       52115     8411.95               5        5   5
#             Shipped         287572   100000.67              28        1  11
# Canada      Shipped         719223   224078.56              70        4  12
# Denmark     Disputed         31218    26012.87               3        4   4
#             Resolved         82616    24078.61               8       11  11
# ...

# %% [markdown]
# ## Menggabungkan DataFrame

# %% [markdown]
# ### **pd.Concat**

# %%
city_data = pd.DataFrame(
    {"revenue":[4200,6500,8000], "employee_count":[5,8,3]},index=['Amsterdam','Toronto','Tokyo'])
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200               5
# Toronto       6500               8
# Tokyo         8000               3

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"])
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
all_city_data = pd.concat([city_data, further_city_data])
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200               5
# Toronto       6500               8
# Tokyo         8000               3
# New York      7000               2
# Barcelona     3400               2

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
pd.concat([all_city_data,city_countries])
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0      NaN      NaN
# Toronto     6500.0             8.0      NaN      NaN
# Tokyo       8000.0             3.0      NaN      NaN
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0      NaN      NaN
# Amsterdam      NaN             NaN  Holland      1.0
# Tokyo          NaN             NaN    Japan      1.0
# Rotterdam      NaN             NaN  Holland      0.0
# Toronto        NaN             NaN   Canada      0.0
# Barcelona      NaN             NaN    Spain      0.0

# %%
pd.concat([all_city_data,city_countries],axis=1)
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Toronto     6500.0             8.0   Canada      0.0
# Tokyo       8000.0             3.0    Japan      1.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %% [markdown]
# ### **pd.Merge**
#
# Menggabungkan dua dataframe berdasarkan satu kolom sebagai kunci
#
# `pd.merge(data1,data2, on='', left_on='', left_index='', right_on='',right_index='',how='')`

# %%
countries = pd.DataFrame({
    "population_millions": [17, 127, 37],
    "continent": ["Europe", "Asia", "North America"]
}, index=["Holland", "Japan", "Canada"])
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
pd.merge(city_countries,countries, left_on='country',right_index = True, how='inner')
# Out:
#            country  capital  population_millions      continent
# Amsterdam  Holland        1                   17         Europe
# Rotterdam  Holland        0                   17         Europe
# Tokyo        Japan        1                  127           Asia
# Toronto     Canada        0                   37  North America

# %%
pd.merge(city_countries,countries, left_on='country',right_index = True, how='left')
# Out:
#            country  capital  population_millions      continent
# Amsterdam  Holland        1                 17.0         Europe
# Tokyo        Japan        1                127.0           Asia
# Rotterdam  Holland        0                 17.0         Europe
# Toronto     Canada        0                 37.0  North America
# Barcelona    Spain        0                  NaN            NaN
