# %% [markdown]
# <a href="https://colab.research.google.com/github/r-ap/TrainingMachineLearning/blob/main/BFI_PYIM_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Matplotlib Anatomy
#
# <img src="https://miro.medium.com/max/419/0*4YHR28Wt4LWg77e3.png"></img>

# %%
plt.plot()
# Out:
# []

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)

# %%
#y = 4x^2 + 2

import numpy as np
x = np.linspace(0,10)

#y = 4*x**2 + 2
y = 2*x**2 - 16*x + 6

plt.plot(x,y)

# %%
#ncols,nrows,figsize=(width,height)
#fig, axes = plt.subplots(ncols=2,figsize=(8,3)) 
#fig, axes = plt.subplots(nrows=2,figsize=(3,8)) 
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8,8))

# %%
fig

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23668/2961011761.py in <module>
# ----> 1 fig.plot()
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %%
axes.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23668/2261588086.py in <module>
# ----> 1 axes.plot()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
type(axes[0])
# Out:
# numpy.ndarray

# %%
axes[0][1].plot(x,y)
axes[0][0].remove()
fig

# %%
import numpy as np
X = np.linspace(0,10)
Y = X**2
axes[0][1].plot(X,Y)
fig

# %%
fig,ax = plt.subplots(ncols=2,figsize=(8,3))
ax[0].plot(X,Y)
ax[1].plot(x,y)

# %%
axes[0][1].plot(x,y)
fig

# %%
data = pd.read_csv('https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/main/sales_data_sample.csv',encoding='Latin-1')
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1       5/7/2003 0:00   Shipped       2         5     2003  ...
# 2       7/1/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818   12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820    3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822    5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %%
data['CITY'].unique()
# Out:
# array(['NYC', 'Reims', 'Paris', 'Pasadena', 'San Francisco', 'Burlingame',
#        'Lille', 'Bergen', 'Melbourne', 'Newark', 'Bridgewater', 'Nantes',
#        'Cambridge', 'Helsinki', 'Stavern', 'Allentown', 'Salzburg',
#        'Chatswood', 'New Bedford', 'Liverpool', 'Madrid', 'Lule',
#        'Singapore', 'South Brisbane', 'Philadelphia', 'Lyon', 'Vancouver',
#        'Burbank', 'New Haven', 'Minato-ku', 'Torino', 'Boras',
#        'Versailles', 'San Rafael', 'Nashua', 'Brickhaven', 'North Sydney',
#        'Montreal', 'Osaka', 'White Plains', 'Kobenhavn', 'London',
#        'Toulouse', 'Barcelona', 'Los Angeles', 'San Diego', 'Bruxelles',
#        'Tsawassen', 'Boston', 'Cowes', 'Oulu', 'San Jose', 'Graz',
#        'Makati City', 'Marseille', 'Koln', 'Gensve', 'Reggio Emilia',
#        'Frankfurt', 'Espoo', 'Dublin', 'Manchester', 'Aaarhus',
#        'Glendale', 'Sevilla', 'Brisbane', 'Strasbourg', 'Las Vegas',
#        'Oslo', 'Bergamo', 'Glen Waverly', 'Munich', 'Charleroi'],
#       dtype=object)

# %% [markdown]
# # Bar Chart
#
# **When to use**:
# - Comparing parts of a bigger set of data, highlighting different categories, or showing change over time.
# - Have long categories label — it offers more space.
# - If you want to illustrate both positive and negative values in the dataset.
#
# **When to avoid**:
# - If you’re using multiple data points.
# - If you have many categories, avoid overloading your graph. Your graph shouldn’t have more than 10 bars.

# %%
data['STATUS'].value_counts()
# Out:
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: STATUS, dtype: int64

# %%
data['STATUS'].value_counts().plot(kind='bar')
data['STATUS'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
data['CITY'].value_counts().plot(kind='bar',figsize=(20,3))

# %%
data['STATUS'].value_counts().plot(kind='bar',color=['red','black','gold','navy','green','cyan'])
plt.text(x=-0.2,y=2619,s=2617)
plt.text(x=0.9,y=61,s=60)
# Out:
# Text(0.9, 61, '60')

# %%
status_count = data['STATUS'].value_counts()
status_count.plot(kind='barh',figsize=(16,5))

for i,loop in enumerate(status_count):
    plt.text(x=loop + 2, y=i-0.1, s=loop)

# %%
data.groupby('STATUS').sum()[['QUANTITYORDERED','ORDERLINENUMBER']].plot(kind='barh')

# %%
data.groupby('STATUS').sum()
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# STATUS
# Cancelled        613878             2038    5061.69              482
# Disputed         145795              597    1252.26               42
# In Process       427330             1490    3251.96              224
# On Hold          457496             1879    3773.99              282
# Resolved         485647             1660    3753.24              334
# Shipped        26830235            91403  219074.93            16890
#
#                  SALES  QTR_ID  MONTH_ID  YEAR_ID    MSRP
# STATUS
# Cancelled    194487.48     152       410   120224    5759
# Disputed      72212.86      28        67    28070    1529
# In Process   144729.96      82       205    82205    4011
# On Hold      178979.19     100       232    88214    4237
# Resolved     150718.28      95       235    94211    4290
# Shipped     9291501.08    7215     18873  5243846  264494

# %%
data.groupby(['STATUS','COUNTRY']).count().plot(kind='bar')
plt.legend(bbox_to_anchor=(1.05, 1),
                         loc='upper left', borderaxespad=0.))

# %%
status_freq = data['STATUS'].value_counts()
status_freq
# Out:
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: STATUS, dtype: int64

# %%
sns.barplot(x=status_freq.index,y=status_freq,orient='v')
# Out:
# <AxesSubplot:ylabel='STATUS'>

# %%
sns.barplot(x=status_freq,y=status_freq.index,orient='h')
# Out:
# <AxesSubplot:xlabel='STATUS'>

# %%
status_freq_multi = data[(data['COUNTRY'] == 'Spain') | (data['COUNTRY'] == 'Sweden')].groupby(['STATUS','COUNTRY']).count()['ORDERNUMBER'].reset_index()
status_freq_multi
# Out:
#        STATUS COUNTRY  ORDERNUMBER
# 0   Cancelled   Spain           16
# 1   Cancelled  Sweden           16
# 2    Disputed   Spain            6
# 3  In Process   Spain            6
# 4     On Hold  Sweden            6
# 5    Resolved   Spain           18
# 6     Shipped   Spain          296
# 7     Shipped  Sweden           35

# %%
sns.barplot(x=status_freq_multi['STATUS'],y=status_freq_multi['ORDERNUMBER'],orient='v',hue=status_freq_multi['COUNTRY'])
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='ORDERNUMBER'>

# %%
status_freq_multi
# Out:
#        STATUS COUNTRY  ORDERNUMBER
# 0   Cancelled   Spain           16
# 1   Cancelled  Sweden           16
# 2    Disputed   Spain            6
# 3  In Process   Spain            6
# 4     On Hold  Sweden            6
# 5    Resolved   Spain           18
# 6     Shipped   Spain          296
# 7     Shipped  Sweden           35

# %%
status_freq_multi = data.groupby(['STATUS','COUNTRY']).count()['ORDERNUMBER'].reset_index()
sns.set(rc = {'figure.figsize':(20,8)})
#sns.barplot(data=status_freq_multi,x='COUNTRY',y='ORDERNUMBER',orient='v',hue='STATUS')

sns.barplot(data=status_freq_multi,x='STATUS',y='ORDERNUMBER',orient='v',hue='COUNTRY')
plt.xticks(rotation=45)
plt.legend(loc='upper center', ncol=6, bbox_to_anchor=(0.5,-0.2))

# %% [markdown]
# # Pie Chart
# **When to use**:
# - When you show relative proportions and percentages of a whole dataset.
# - Best used with small datasets — also applies to donut charts.
# - When comparing the effect of ONE factor on different categories.
# - If you have up to 6 categories.
# - When your data is nominal and not ordinal.
#
# **When to avoid**:
# - If you have a big dataset.
# - If you want to make a precise or absolute comparison between values.

# %%
data['COUNTRY'].value_counts().plot(kind='pie', figsize=(10,10), autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='COUNTRY'>

# %%
data['STATUS'].value_counts().plot(kind='pie', figsize=(10,10), autopct='%.2f%%')
plt.legend()

# %%
data.groupby(['COUNTRY','STATUS']).count()['ORDERNUMBER'].plot(kind='pie', figsize=(20,20), autopct='%.2f%%')
plt.legend(loc='upper center', ncol=6, bbox_to_anchor=(0.5,0))

# %% [markdown]
# # Line Chart
#
# **When to use**:
# - If you have a continuous dataset that changes over time.
# - If your dataset is too big for a bar chart.
# - If you want to display multiple series for the same timeline.
# - If you want to visualize trends instead of exact values.
#
# **When to avoid**:
# - Line charts work better with bigger datasets, so, if you have a small one, use a bar chart instead.

# %%
data['ORDERDATE'] = data['ORDERDATE'].astype('datetime64[ns]')

sorted_data = data.sort_values(by='ORDERDATE',ascending=True).groupby('ORDERDATE').sum()

fig, axes = plt.subplots(ncols=2)
sorted_data['SALES'].plot(kind='line',ax=axes[1])
sorted_data['ORDERNUMBER'].plot(kind='line',ax=axes[0])
axes[0].set_title('ORDER NUMBER')
axes[1].set_title('SALES')
axes[1].set_xlabel('Tanggal')
# Out:
# Text(0.5, 0, 'Tanggal')

# %%
fig, axes = plt.subplots(nrows=2,figsize=(20,15))
axes[0].plot(sorted_data.index,sorted_data['SALES'])
axes[1].plot(sorted_data.index,sorted_data['QUANTITYORDERED'])
#plt.xticks(rotation=45)
axes[0].set_xticklabels(sorted_data.index,rotation=45)
axes[1].set_xticklabels(sorted_data.index,rotation=45)
#axes[0].set_ylim(100,10000)
plt.show()
# Out:
# C:\Users\010497\AppData\Local\Temp/ipykernel_23668/4075265555.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(sorted_data.index,rotation=45)
# C:\Users\010497\AppData\Local\Temp/ipykernel_23668/4075265555.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(sorted_data.index,rotation=45)

# %%
sorted_data.index
# Out:
# DatetimeIndex(['2003-01-06', '2003-01-09', '2003-01-10', '2003-01-29',
#                '2003-01-31', '2003-02-11', '2003-02-17', '2003-02-24',
#                '2003-03-03', '2003-03-10',
#                ...
#                '2005-05-03', '2005-05-05', '2005-05-06', '2005-05-09',
#                '2005-05-10', '2005-05-13', '2005-05-17', '2005-05-29',
#                '2005-05-30', '2005-05-31'],
#               dtype='datetime64[ns]', name='ORDERDATE', length=252, freq=None)

# %%
fig, axes = plt.subplots(ncols=2,figsize=(20,5))
sns.lineplot(x=sorted_data.index,y=sorted_data['SALES'],ax=axes[0])
sns.lineplot(x=sorted_data.index,y=sorted_data['QUANTITYORDERED'],ax=axes[1])
#plt.xticks(rotation=45)
axes[0].set_xticklabels(sorted_data.index,rotation=45)
axes[1].set_xticklabels(sorted_data.index,rotation=45)
plt.show()
# Out:
# C:\Users\010497\AppData\Local\Temp/ipykernel_23668/3754817737.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(sorted_data.index,rotation=45)
# C:\Users\010497\AppData\Local\Temp/ipykernel_23668/3754817737.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(sorted_data.index,rotation=45)

# %%
fig, axes = plt.subplots(ncols=2,figsize=(10,5))
sorted_data['SALES'].plot(ax=axes[0])
sorted_data['QUANTITYORDERED'].plot(ax=axes[1])
axes[0].set_title('Pendapatan Harian')
axes[1].set_title('Jumlah Produk yang Terjual Harian')
# Out:
# Text(0.5, 1.0, 'Jumlah Produk yang Terjual Harian')

# %%
sns.lineplot(x=sorted_data.index,y=sorted_data['QUANTITYORDERED'])
plt.xticks(rotation=45)
plt.show()

# %%
sorted_data

# %% [markdown]
# # Scatter Plot
# **When to use**:
# - To show correlation and clustering in big datasets.
# - If your dataset contains points that have a pair of values.
# - If the order of points in the dataset is not essential.
#
# **When to avoid**:
# - If you have a small dataset.
# - If the values in your dataset are not correlated.

# %%
fig,axes = plt.subplots(figsize=(10,10))
axes.scatter(data['QUANTITYORDERED'],data['SALES'])
axes.set_xlabel('QUANTIRY ORDERED')
axes.set_ylabel('SALES')
axes.set_title('Relationship between Quantity Ordered and Sales')
# Out:
# Text(0.5, 1.0, 'Relationship between Quantity Ordered and Sales')

# %%
sns.scatterplot(data=data,x='QUANTITYORDERED',y='SALES')

# %% [markdown]
# # Bubble Plot
# **When to use**:
# - If you want to compare independent values.
# - If you want to show distribution or relation.
# **When to avoid**:
# - If you have a small dataset.

# %%
sns.scatterplot(data=data,x='QUANTITYORDERED',y='SALES',size='STATUS',sizes=(10,1000))
# Out:
# <AxesSubplot:xlabel='QUANTITYORDERED', ylabel='SALES'>

# %%
sns.scatterplot(data=data,x='QUANTITYORDERED',y='SALES',style='STATUS')
# Out:
# <AxesSubplot:xlabel='QUANTITYORDERED', ylabel='SALES'>

# %%
sns.scatterplot(data=data,x='QUANTITYORDERED',y='SALES',hue='STATUS')
# Out:
# <AxesSubplot:xlabel='QUANTITYORDERED', ylabel='SALES'>

# %%
sns.scatterplot(data=data,x='QUANTITYORDERED',y='SALES',style='STATUS', size='TERRITORY',sizes=(10,100), hue='COUNTRY')
# Out:
# <AxesSubplot:xlabel='QUANTITYORDERED', ylabel='SALES'>

# %% [markdown]
# # Area Plot
# **When to use**:
# - If you want to show part-to-whole relations.
# - If you want to portray the volume of your data and not just the relation to time.
# **When to avoid**:
# - It can’t be used with discrete data.

# %%
sorted_data['SALES'].plot(kind='area',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='ORDERDATE'>

# %%
sorted_data['SALES'].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='ORDERDATE'>

# %%
sorted_data['SALES'].plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>
